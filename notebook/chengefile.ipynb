# %%
import pandas as pd

data = pd.read_csv('../input/child-mind-institute-problematic-internet-use/fillchatgpt001_train.csv')

# %%
gptdata = data[data["gptdata"] == 1]
rawdata = data[data["gptdata"] == 0]
#プロット
#gptdataとrawdataのsiiの分布を比較
import matplotlib.pyplot as plt 
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.kdeplot(gptdata["sii"], label="gptdata")
sns.kdeplot(rawdata["sii"], label="rawdata")
plt.legend()
plt.show()
gptdata["sii"].value_counts()
# Out:
# sii
#  0.0    674
#  1.0    400
# -1.0    150
# Name: count, dtype: int64

# %%
data = pd.read_csv('../input/child-mind-institute-problematic-internet-use/fillchatgpt001_train.csv')
data["sii"] =(data["gptdata"]-1)*-1 * data["sii"] + data["gptdata"]*(data["PCIAT-PCIAT_Total"] //50+(data["PCIAT-PCIAT_Total"] //50>=1))
data
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# ...
